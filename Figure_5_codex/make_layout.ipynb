# %%
# %matplotlib inline
import numpy as np
import scanpy as sc
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rcParams

# %%
adata = sc.read_h5ad("/storage/codex/datasets_v1/bladder_merged_v10.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 598327 × 1440
#     obs: 'CD45_ringpct', 'CD20_ringpct', 'CD3e_ringpct', 'CD45RO_ringpct', 'CD45RA_ringpct', 'CD8_ringpct', 'CD4_ringpct', 'CDH12_ringpct', 'KRT13_ringpct', 'KRT17_ringpct', 'PanCytoK_ringpct', 'ERBB2_ringpct', 'sample_id', 'sample_id_printing', 'snSeq_sample', 'patient', 'biopsy', 'Filtered_DAPI', 'cell_gates', 'celltype_gating', 'subtype_gates', 'subtype_gating', 'subtype_rescued', 'subtype', 'celltype', 'cell_niches', 'niche_labels'
#     uns: 'celltype_colors', 'channels', 'niche_labels_colors', 'niche_profiles_colnames', 'patient_colors', 'sample_id_printing_colors', 'sample_layout', 'snSeq_sample_colors', 'subtype_colors', 'subtype_gating_colors'
#     obsm: 'coordinates', 'coordinates_shift', 'niche_profiles'

# %%
sample_layout_1 = np.stack([
    np.array(['pass', 
  'pass',
  'pass',
  '210226_Bladder_TMA1_reg1_v5',
#   '210226_Bladder_TMA1_reg2_v5',
#   '210226_Bladder_TMA1_reg3_v5'
  'pass',
  'pass',
  'pass',
   ]),
 np.array([
#   '210226_Bladder_TMA1_reg4_v5',
  'pass',
  '210226_Bladder_TMA1_reg5_v5',
#   '210226_Bladder_TMA1_reg6_v5',
  'pass',
  '210226_Bladder_TMA1_reg7_v5',
  '210226_Bladder_TMA1_reg8_v5',
  '210226_Bladder_TMA1_reg9_v5',
  '210226_Bladder_TMA1_reg10_v5'])[::-1],
 np.array([
#   '210226_Bladder_TMA1_reg11_v5',
  'pass',
  '210226_Bladder_TMA1_reg12_v5',
  '210226_Bladder_TMA1_reg13_v5',
  '210226_Bladder_TMA1_reg14_v5',
  '210226_Bladder_TMA1_reg15_v5',
#   '210226_Bladder_TMA1_reg16_v5',
#   '210226_Bladder_TMA1_reg17_v5'
  'pass',
  'pass',
 ]),
 np.array([
  '210226_Bladder_TMA1_reg18_v5',
  '210226_Bladder_TMA1_reg19_v5',
  '210226_Bladder_TMA1_reg20_v5',
#   '210226_Bladder_TMA1_reg21_v5',
#   '210226_Bladder_TMA1_reg22_v5',
#   '210226_Bladder_TMA1_reg23_v5',
#   '210226_Bladder_TMA1_reg24_v5'
  'pass',
  'pass',
  'pass',
  'pass',
  ])[::-1],
 np.array([
  '210226_Bladder_TMA1_reg25_v5',
  '210226_Bladder_TMA1_reg26_v5',
#   '210226_Bladder_TMA1_reg27_v5',
  'pass',
  '210226_Bladder_TMA1_reg28_v5',
  '210226_Bladder_TMA1_reg29_v5',
  '210226_Bladder_TMA1_reg30_v5',
  '210226_Bladder_TMA1_reg31_v5']),
 np.array([
  'pass',
  '210226_Bladder_TMA1_reg32_v5',
  '210226_Bladder_TMA1_reg33_v5',
  '210226_Bladder_TMA1_reg34_v5',
#   '210226_Bladder_TMA1_reg35_v5',
  'pass',
  '210226_Bladder_TMA1_reg36_v5',
  '210226_Bladder_TMA1_reg37_v5'])[::-1],
], axis=0)
                         
print(sample_layout_1.shape)

sample_layout_2 = np.stack([
    np.array(['pass', 
  'pass',
  'pass',
  'pass',
  '210308_Bladder_TMA2_reg1_v5',
#   '210308_Bladder_TMA2_reg2_v5',
  'pass',
  '210308_Bladder_TMA2_reg3_v5',
  ]),
 np.array([
  'pass',
  '210308_Bladder_TMA2_reg4_v5',
  '210308_Bladder_TMA2_reg5_v5',
  '210308_Bladder_TMA2_reg6_v5',
  '210308_Bladder_TMA2_reg7_v5',
  '210308_Bladder_TMA2_reg8_v5',
  '210308_Bladder_TMA2_reg9_v5',
  ])[::-1],
 np.array([
#   '210308_Bladder_TMA2_reg10_v5',
  'pass',
  '210308_Bladder_TMA2_reg11_v5',
  '210308_Bladder_TMA2_reg12_v5',
  '210308_Bladder_TMA2_reg13_v5',
  '210308_Bladder_TMA2_reg14_v5',
  '210308_Bladder_TMA2_reg15_v5',
  '210308_Bladder_TMA2_reg16_v5',
 ]),
 np.array([
  '210308_Bladder_TMA2_reg17_v5',
  '210308_Bladder_TMA2_reg18_v5',
  '210308_Bladder_TMA2_reg19_v5',
  '210308_Bladder_TMA2_reg20_v5',
#   '210308_Bladder_TMA2_reg21_v5',
#   '210308_Bladder_TMA2_reg22_v5',
  '210308_Bladder_TMA2_reg23_v5',
#   'pass',
  'pass',
  'pass',
 ])[::-1],
 np.array([
  '210308_Bladder_TMA2_reg24_v5',
  '210308_Bladder_TMA2_reg25_v5',
#   '210308_Bladder_TMA2_reg26_v5',
  'pass',
  '210308_Bladder_TMA2_reg27_v5',
  '210308_Bladder_TMA2_reg28_v5',
  '210308_Bladder_TMA2_reg29_v5',
  '210308_Bladder_TMA2_reg30_v5',
 ]),
 np.array([
  'pass',
  '210308_Bladder_TMA2_reg31_v5',
  '210308_Bladder_TMA2_reg32_v5',
  '210308_Bladder_TMA2_reg33_v5',
#   '210308_Bladder_TMA2_reg34_v5',
  'pass',
  '210308_Bladder_TMA2_reg35_v5',
  '210308_Bladder_TMA2_reg36_v5',
  ])[::-1],
], axis=0)

print(sample_layout_2.shape)

sample_layout_3 = np.stack(
    [np.array([
  'pass', 
  'pass',
  'pass',
  'pass',
#   '210311_Bladder_TMA3_reg1_v5',
#   '210311_Bladder_TMA3_reg2_v5',
#   '210311_Bladder_TMA3_reg3_v5',
  'pass',
  'pass',
  'pass',
 ]),
 np.array([
  'pass',
  '210311_Bladder_TMA3_reg4_v5',
  '210311_Bladder_TMA3_reg5_v5',
  '210311_Bladder_TMA3_reg6_v5',
#   '210311_Bladder_TMA3_reg7_v5',
#   '210311_Bladder_TMA3_reg8_v5',
  'pass',
  'pass',
  '210311_Bladder_TMA3_reg9_v5',
 ])[::-1],
 np.array([
  '210311_Bladder_TMA3_reg10_v5',
  '210311_Bladder_TMA3_reg11_v5',
  '210311_Bladder_TMA3_reg12_v5',
  'pass',
  '210311_Bladder_TMA3_reg13_v5',
#   '210311_Bladder_TMA3_reg14_v5',
#   '210311_Bladder_TMA3_reg15_v5',
  'pass',
  'pass',
 ]),
 np.array([
  '210311_Bladder_TMA3_reg16_v5',
  '210311_Bladder_TMA3_reg17_v5',
  '210311_Bladder_TMA3_reg18_v5',
#   '210311_Bladder_TMA3_reg19_v5',
#   '210311_Bladder_TMA3_reg20_v5',
#   '210311_Bladder_TMA3_reg21_v5',
  'pass',
  'pass',
  'pass',
  '210311_Bladder_TMA3_reg22_v5',
 ])[::-1],
 np.array([
#   '210311_Bladder_TMA3_reg23_v5',
  'pass',
  '210311_Bladder_TMA3_reg24_v5',
#   '210311_Bladder_TMA3_reg25_v5',
  'pass',
  '210311_Bladder_TMA3_reg26_v5',
  '210311_Bladder_TMA3_reg27_v5',
  '210311_Bladder_TMA3_reg28_v5',
  '210311_Bladder_TMA3_reg29_v5',
 ]),
 np.array(['pass',
  '210311_Bladder_TMA3_reg30_v5',
  '210311_Bladder_TMA3_reg31_v5',
#   '210311_Bladder_TMA3_reg32_v5',
#   '210311_Bladder_TMA3_reg33_v5',
  'pass',
  'pass',
  '210311_Bladder_TMA3_reg34_v5',
  '210311_Bladder_TMA3_reg35_v5', 
          ])[::-1],
], axis=0)


print(sample_layout_3.shape)

sample_layout_top_row = np.concatenate([sample_layout_1,  sample_layout_2, ], axis=1)
blanks = np.zeros_like(sample_layout_3)
blanks[:] = 'pass'
top_row = np.concatenate([sample_layout_1,  sample_layout_2, ], axis=1)
bottom_row = np.concatenate([sample_layout_3,  blanks, ], axis=1)
sample_layout = np.concatenate([top_row, bottom_row], axis=0)
                               
#                                 sample_layout_3], axis=0)
print(sample_layout)
print(sample_layout.shape)
# Out:
# (6, 7)

# %%
ncol = 9
arrangement = []
i = 0
this_row = []
for u in np.unique(adata.obs.patient):
    sp = np.unique(adata.obs.loc[adata.obs.patient==u, 'sample_id'])
    if (len(this_row) + len(sp)) > ncol:
        d = ncol - len(this_row)
        this_row += ['pass']*d
        arrangement.append(np.array(this_row, dtype=object))
        this_row = []
    for s in sp:
        this_row.append(s)
        
if (len(this_row) + len(sp)) > ncol:
    d = ncol - len(this_row)
    this_row += ['pass']*d
arrangement.append(np.array(this_row))
sample_layout = np.array(arrangement)
print(sample_layout)
# Out:
# [['210226_Bladder_TMA1_reg33_v5' '210308_Bladder_TMA2_reg32_v5'
#   '210311_Bladder_TMA3_reg31_v5' '210226_Bladder_TMA1_reg32_v5'
#   '210308_Bladder_TMA2_reg31_v5' '210311_Bladder_TMA3_reg30_v5'
#   '210308_Bladder_TMA2_reg5_v5' '210311_Bladder_TMA3_reg5_v5' 'pass']
#  ['210226_Bladder_TMA1_reg5_v5' '210308_Bladder_TMA2_reg4_v5'
#   '210311_Bladder_TMA3_reg4_v5' '210311_Bladder_TMA3_reg10_v5'
#   '210226_Bladder_TMA1_reg12_v5' '210308_Bladder_TMA2_reg11_v5'
#   '210311_Bladder_TMA3_reg11_v5' 'pass' 'pass']
#  ['210226_Bladder_TMA1_reg13_v5' '210308_Bladder_TMA2_reg12_v5'
#   '210311_Bladder_TMA3_reg12_v5' '210308_Bladder_TMA2_reg3_v5'
#   '210226_Bladder_TMA1_reg10_v5' '210308_Bladder_TMA2_reg9_v5'
#   '210311_Bladder_TMA3_reg9_v5' '210226_Bladder_TMA1_reg9_v5'
#   '210308_Bladder_TMA2_reg8_v5']
#  ['210226_Bladder_TMA1_reg8_v5' '210308_Bladder_TMA2_reg7_v5'
#   '210226_Bladder_TMA1_reg14_v5' '210308_Bladder_TMA2_reg13_v5'
# ...

# %%
def shift_coordinates(adata, sample_layout):
    # rows and columns are flipped again
    
    nr,nc = sample_layout.shape
    print('layout', nr,nc)
    
    coords = adata.obsm['coordinates'].copy()
    coords[:,1] = -coords[:,1]
    #coords_tmp = coords.copy()
    
    row_shift_grid = np.zeros_like(sample_layout, dtype=np.int)
    col_shift_grid = np.zeros_like(sample_layout, dtype=np.int)
        
    # Cycle through once and find the shifts
    print('ranges', nr, nc)
    for r2 in range(nr):
        print('row', r2)
        if r2>0:
            ref_row = r2-1 if r2>0 else r2
            print('\treference row:', ref_row)
            row_shift = current_row_max
            print('\trow shift:', row_shift)
        else: 
            row_shift = 0
        
        current_row_max = 0
        for c2 in range(nc):
            print('\tcolumn', c2)
            if r2==0 and c2==0: continue
            
            print('\t\tlocation', r2, c2)
            target_slide = sample_layout[r2,c2]
            if target_slide == 'pass':
                continue
            if target_slide is None:
                continue
            print('\t\ttarget slide:', target_slide)
            target_idx = adata.obs.sample_id.values==target_slide
            target_coords = coords[target_idx].copy()
            print('\t\tstart:', max(target_coords[:,0]), max(target_coords[:,1]))
            dx = max(target_coords[:,0])-min(target_coords[:,0])
            dy = max(target_coords[:,1])-min(target_coords[:,1])
            print('\t\tdimensions:', dx, dy)
            
            row_shift_grid[r2,c2] = dy
            col_shift_grid[r2,c2] = dx
            
    row_shift_vect = np.max(row_shift_grid, axis=1)
    col_shift_vect = np.max(col_shift_grid, axis=0)
    for r in range(nr):
        print('row', r)
        rshift = 0 if r == 0 else np.sum(row_shift_vect[:r])
        for c in range(nc):
            print('\tcolumn', c)
            cshift = 0 if c == 0 else np.sum(col_shift_vect[:c])
            if r == 0 and c == 0: continue
            print('\t\tlocation', r, c)
            target_slide = sample_layout[r,c]
            if target_slide == 'pass':
                continue
            if target_slide is None:
                continue
            print('\t\ttarget slide:', target_slide)
            print(f'\t\tShifting by: rshift(1):{rshift}\tcshift(0):{cshift}')
            target_idx = adata.obs.sample_id.values==target_slide
            target_coords = coords[target_idx].copy()
            target_coords[:,0] -= min(target_coords[:,0])
            target_coords[:,1] -= min(target_coords[:,1])
            target_coords[:,0] += cshift
            target_coords[:,1] += rshift
            coords[target_idx] = target_coords
            
    # Flip dim1 (vertical dimension)
    coords[:,1] = -coords[:,1]
    return coords, row_shift_grid, col_shift_grid
    
print(sample_layout)
shifted_coords, row_shift_grid, col_shift_grid = shift_coordinates(adata, sample_layout)
adata.obsm['coordinates_shift_patient'] = shifted_coords
adata.uns['sample_layout_patient'] = sample_layout
# Out:
# [['210226_Bladder_TMA1_reg33_v5' '210308_Bladder_TMA2_reg32_v5'
#   '210311_Bladder_TMA3_reg31_v5' '210226_Bladder_TMA1_reg32_v5'
#   '210308_Bladder_TMA2_reg31_v5' '210311_Bladder_TMA3_reg30_v5'
#   '210308_Bladder_TMA2_reg5_v5' '210311_Bladder_TMA3_reg5_v5' 'pass']
#  ['210226_Bladder_TMA1_reg5_v5' '210308_Bladder_TMA2_reg4_v5'
#   '210311_Bladder_TMA3_reg4_v5' '210311_Bladder_TMA3_reg10_v5'
#   '210226_Bladder_TMA1_reg12_v5' '210308_Bladder_TMA2_reg11_v5'
#   '210311_Bladder_TMA3_reg11_v5' 'pass' 'pass']
#  ['210226_Bladder_TMA1_reg13_v5' '210308_Bladder_TMA2_reg12_v5'
#   '210311_Bladder_TMA3_reg12_v5' '210308_Bladder_TMA2_reg3_v5'
#   '210226_Bladder_TMA1_reg10_v5' '210308_Bladder_TMA2_reg9_v5'
#   '210311_Bladder_TMA3_reg9_v5' '210226_Bladder_TMA1_reg9_v5'
#   '210308_Bladder_TMA2_reg8_v5']
#  ['210226_Bladder_TMA1_reg8_v5' '210308_Bladder_TMA2_reg7_v5'
#   '210226_Bladder_TMA1_reg14_v5' '210308_Bladder_TMA2_reg13_v5'
# ...

# %%
rcParams['figure.dpi'] = 300
rcParams['figure.facecolor'] = (1,1,1,1)
r = np.max(np.abs(adata.obsm['coordinates_shift']), axis=0)
r = r[0]/r[1]
plt.figure(figsize=(r*3,3)) 
sc.pl.embedding(adata, basis='coordinates_shift', color='sample_id_printing', 
                ax=plt.gca(),  
                legend_fontoutline=0.5,
                legend_fontsize=2,
                legend_loc='on data'
               )

# %%
r = np.max(np.abs(adata.obsm['coordinates_shift_patient']), axis=0)
r = r[0]/r[1]
plt.figure(figsize=(r*3,3)) 
sc.pl.embedding(adata, basis='coordinates_shift_patient', color='patient',  ax=plt.gca(),  
                legend_fontoutline=0.5,
                legend_fontsize=4,
                legend_loc='on data'
               )

# %%
import pandas as pd

color_dict = {k:c for k,c in zip(np.unique(adata.obs.subtype), adata.uns['subtype_colors'])}
color_dict['Epithelial'] = '#bcbd22'
color_dict['Epithelial_KRT13_KRT17'] = '#bcbd22'
color_dict['Epithelial_KRT13'] = '#bcbd22'
color_dict['Epithelial_CDH'] = '#1f77b4'
color_dict['Endothelial'] = '#17becf'
color_dict['CD8T_exhausted'] = '#e377c2'
color_dict['CD4T'] = '#ff9896'
color_dict['Stromal'] = '#98df8a'
color_dict['Mac'] = '#aec7e8'
color_dict['Bcell'] = '#ab09ab'

# master_palette = {
#     "ACTA2_Fibroblast": "#ffbb78", 
#     "APC_Macrophage": "#7f7f7f", 
#     "Activated_Bcell": "#c5b0d5", 
#     "CDH12_CDH18_Epithelial": "#1f77b4", 
#     "DSG3_Epithelial": "#ff7f0e", 
#     "Dendritic_cell": "#c49c94", 
#     "Endothelial": "#17becf", 
#     "FAP_Fibroblast": "#8c564b", 
#     "Inflam_Macrophage": "#aec7e8", 
#     "Intermediate_Epithelial": "#2ca02c", 
#     "KRT_Epithelial": "#9467bd", 
#     "Late_Activation_CD8T": "#e377c2", 
#     "Naive_Tcell": "#ff9896", 
#     "PDGFRB_Fibroblast": "#f7b6d2", 
#     "PDPN_Fibroblast": "#98df8a", 
#     "Plasma_Bcell": "#c7c7c7", 
#     "Proliferating_Epithelial": "#d62728", 
#     "Treg": "#dbdb8d", 
#     "KRT_13_17_Epithelial": "#bcbd22", 
# }


p = []
for u in np.unique(adata.obs.celltype):
    p.append(color_dict[u])
adata.uns['celltype_colors'] = p



# Use a slightly different green for the "subtype" Epithelial cells
color_dict['Epithelial'] = '#afc499'

subtype_2 = np.array(adata.obs.subtype)
subtype_2[subtype_2 == 'Epithelial_KRT13'] = 'Epithelial_KRT13_KRT17'
subtype_2[subtype_2 == 'Epithelial_KRT17'] = 'Epithelial_KRT13_KRT17'
adata.obs['subtype_2'] = pd.Categorical(subtype_2)

p = []
for u in np.unique(subtype_2):
    p.append(color_dict[u])
adata.uns['subtype_2_colors'] = p

# %%
# sc.settings.figdir = 'figures'
# rcParams['figure.dpi']  = 600
# r = np.max(np.abs(adata.obsm['coordinates_shift_patient']), axis=0)
# r = r[0]/r[1]
# plt.figure(figsize=(r*15,15)) 
# fig = sc.pl.embedding(adata, basis='coordinates_shift_patient', color='subtype_2',  ax=plt.gca(),  
# #                 legend_fontoutline=0.5,
# #                 legend_fontsize=4,
# #                 legend_loc='None',
#                 size=3,
#                 save = '_subtype.png'
#                )

# %%
# sc.settings.figdir = 'figures'
# plt.figure(figsize=(r*15,15)) 
# sc.pl.embedding(adata, basis='coordinates_shift_patient', color='celltype',  ax=plt.gca(),  
# #                 legend_fontoutline=0.5,
# #                 legend_fontsize=4,
# #                 legend_loc=None,
#                 size=3,
#                 save = '_celltype.png'
#                )

# %%
# sc.settings.figdir = 'figures'
# plt.figure(figsize=(r*15,15)) 
# sc.pl.embedding(adata, basis='coordinates_shift_patient', color='niche_labels',  ax=plt.gca(),  
# #                 legend_fontoutline=0.5,
# #                 legend_fontsize=4,
# #                 legend_loc=None,
#                 size=3,
#                 save = '_niche_label.png'
#                )

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 598327 × 1440
#     obs: 'CD45_ringpct', 'CD20_ringpct', 'CD3e_ringpct', 'CD45RO_ringpct', 'CD45RA_ringpct', 'CD8_ringpct', 'CD4_ringpct', 'CDH12_ringpct', 'KRT13_ringpct', 'KRT17_ringpct', 'PanCytoK_ringpct', 'ERBB2_ringpct', 'sample_id', 'sample_id_printing', 'snSeq_sample', 'patient', 'biopsy', 'Filtered_DAPI', 'cell_gates', 'celltype_gating', 'subtype_gates', 'subtype_gating', 'subtype_rescued', 'subtype', 'celltype', 'cell_niches', 'niche_labels'
#     uns: 'celltype_colors', 'channels', 'niche_labels_colors', 'niche_profiles_colnames', 'patient_colors', 'sample_id_printing_colors', 'sample_layout', 'snSeq_sample_colors', 'subtype_colors', 'subtype_gating_colors'
#     obsm: 'coordinates', 'coordinates_shift', 'niche_profiles'
